# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import pandas as pd

# %%
import os
os.chdir('/home/hrayrh/projects/incontext_spurious/')

# %%
# assuming in the figsize height = 5
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = plt.rcParams['xtick.labelsize']
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['grid.linewidth'] = 0.5
plt.rcParams['grid.alpha'] = 0.25
# Make sure no Type 3 fonts are used. Such fonts are not accepted by some conferences/journals.
plt.rcParams['pdf.fonttype'] = 42
if seaborn is not None:
    seaborn.set_style("whitegrid")

# %%
no_rotate_eval_path = 'outputs/runs/evaluate/2b1d5bf7df8f4ab18062551a/2024-11-23_03-25-29'
with_rotate_eval_path = 'outputs/runs/evaluate/2b1d5bf7df8f4ab18062551a/2024-11-23_03-47-55'

# %%
def read_eval(eval_path):
    df = pd.read_csv(os.path.join(eval_path, 'val_train_test.csv'))
    return df.sort_values('context_class_size')

# %%
no_rotate_eval_df = read_eval(no_rotate_eval_path)
with_rotate_eval_df = read_eval(with_rotate_eval_path)

# %%
no_rotate_eval_df
# Out:
#    Unnamed: 0  context_class_size      accuracy accuracy_minority  \
# 0           0                   1  67.70 ± 0.00      68.37 ± 0.00
# 1           1                   2  74.98 ± 0.00      71.30 ± 0.00
# 2           2                   4  81.58 ± 0.00      76.53 ± 0.00
# 3           3                   8  86.30 ± 0.00      82.21 ± 0.00
# 4           4                  16  89.84 ± 0.00      86.19 ± 0.00
# 5           5                  32  92.08 ± 0.00      88.91 ± 0.00
# 6           6                  64  93.99 ± 0.00      90.81 ± 0.00
# 7           7                 128  95.32 ± 0.00      92.77 ± 0.00
# 8           8                 256  95.68 ± 0.00      92.88 ± 0.00
#
#   accuracy_majority worst_group_accuracy group_0_accuracy group_1_accuracy  \
# 0      66.70 ± 0.00         63.01 ± 0.00     72.91 ± 0.00     67.22 ± 0.00
# 1      77.20 ± 0.00         71.31 ± 0.00     78.13 ± 0.00     71.31 ± 0.00
# 2      86.19 ± 0.00         74.90 ± 0.00     87.13 ± 0.00     78.38 ± 0.00
# 3      90.28 ± 0.00         81.92 ± 0.00     91.26 ± 0.00     82.35 ± 0.00
# 4      93.46 ± 0.00         84.24 ± 0.00     95.11 ± 0.00     87.82 ± 0.00
# 5      94.97 ± 0.00         86.50 ± 0.00     96.08 ± 0.00     91.38 ± 0.00
# 6      96.75 ± 0.00         89.51 ± 0.00     97.93 ± 0.00     92.93 ± 0.00
# 7      97.57 ± 0.00         91.37 ± 0.00     98.67 ± 0.00     94.33 ± 0.00
# 8      98.62 ± 0.00         91.55 ± 0.00     99.35 ± 0.00     94.14 ± 0.00
#
#   group_2_accuracy group_3_accuracy
# 0     63.01 ± 0.00     67.50 ± 0.00
# 1     71.88 ± 0.00     78.66 ± 0.00
# 2     74.90 ± 0.00     85.95 ± 0.00
# 3     81.92 ± 0.00     89.93 ± 0.00
# 4     84.24 ± 0.00     92.18 ± 0.00
# 5     86.50 ± 0.00     94.24 ± 0.00
# 6     89.51 ± 0.00     95.70 ± 0.00
# 7     91.37 ± 0.00     96.99 ± 0.00
# 8     91.55 ± 0.00     97.83 ± 0.00

# %%
with_rotate_eval_df
# Out:
#    Unnamed: 0  context_class_size      accuracy accuracy_minority  \
# 0           0                   1  66.87 ± 0.00      68.09 ± 0.00
# 1           1                   2  74.46 ± 0.00      71.44 ± 0.00
# 2           2                   4  79.87 ± 0.00      74.54 ± 0.00
# 3           3                   8  85.11 ± 0.00      80.94 ± 0.00
# 4           4                  16  88.68 ± 0.00      84.55 ± 0.00
# 5           5                  32  91.78 ± 0.00      88.50 ± 0.00
# 6           6                  64  94.10 ± 0.00      91.70 ± 0.00
# 7           7                 128  95.42 ± 0.00      93.12 ± 0.00
# 8           8                 256  95.80 ± 0.00      93.60 ± 0.00
#
#   accuracy_majority worst_group_accuracy group_0_accuracy group_1_accuracy  \
# 0      65.05 ± 0.00         63.60 ± 0.00     70.42 ± 0.00     65.80 ± 0.00
# 1      77.76 ± 0.00         69.37 ± 0.00     78.88 ± 0.00     72.98 ± 0.00
# 2      84.50 ± 0.00         71.50 ± 0.00     87.23 ± 0.00     77.37 ± 0.00
# 3      89.25 ± 0.00         78.50 ± 0.00     91.31 ± 0.00     82.95 ± 0.00
# 4      92.73 ± 0.00         81.91 ± 0.00     94.82 ± 0.00     87.22 ± 0.00
# 5      94.50 ± 0.00         86.55 ± 0.00     96.38 ± 0.00     90.87 ± 0.00
# 6      96.37 ± 0.00         90.09 ± 0.00     97.78 ± 0.00     93.42 ± 0.00
# 7      97.46 ± 0.00         91.52 ± 0.00     98.97 ± 0.00     94.81 ± 0.00
# 8      98.31 ± 0.00         92.36 ± 0.00     99.10 ± 0.00     94.73 ± 0.00
#
#   group_2_accuracy group_3_accuracy
# 0     63.60 ± 0.00     67.55 ± 0.00
# 1     69.37 ± 0.00     76.68 ± 0.00
# 2     71.50 ± 0.00     83.40 ± 0.00
# 3     78.50 ± 0.00     87.74 ± 0.00
# 4     81.91 ± 0.00     90.76 ± 0.00
# 5     86.55 ± 0.00     93.25 ± 0.00
# 6     90.09 ± 0.00     95.21 ± 0.00
# 7     91.52 ± 0.00     96.45 ± 0.00
# 8     92.36 ± 0.00     97.16 ± 0.00

# %%
def parse_mean(eval_values):
    ret = []
    for x in eval_values:
        ret.append(float(x.split('±')[0]))
    return np.array(ret)


def plot_results(
    no_rotate_eval_df,
    with_rotate_eval_df,
    metric,
    save_name=None):

    fig, ax = plt.subplots(figsize=(7, 5))

    assert np.allclose(
        no_rotate_eval_df['context_class_size'],
        with_rotate_eval_df['context_class_size']
    )
    context_len = 2*np.array(no_rotate_eval_df['context_class_size'])
    
    ax.plot(context_len,
            parse_mean(no_rotate_eval_df[metric]), 
            '-o',
            label='Standard evaluation')

    ax.plot(context_len,
            parse_mean(with_rotate_eval_df[metric]),
            '-x',
            label='Evaluating with randomly rotated embeddings')
    
    # customize the plot
    if metric.find('worst_group_accuracy') != -1:
        ax.set_ylabel('Worst-group accuracy')
    elif metric.find('minority') != -1:
        ax.set_ylabel('Minority-group accuracy')
    elif metric.find('majority') != -1:
        ax.set_ylabel('Majority-group accuracy')
    else:
        ax.set_ylabel('Overall accuracy')

    ax.set_xlabel('Number of context examples')
    ax.set_xscale('log')
    ax.set_xticks(context_len)
    ax.set_xticklabels(context_len)
    ax.legend()
    fig.tight_layout()

    if save_name:
        fig.savefig(f'plots/{save_name}_{metric}.pdf')

    return fig, ax

# %%
plot_results(
    no_rotate_eval_df=no_rotate_eval_df,
    with_rotate_eval_df=with_rotate_eval_df,
    metric='accuracy_majority',
    save_name='data_leakage'
)

plot_results(
    no_rotate_eval_df=no_rotate_eval_df,
    with_rotate_eval_df=with_rotate_eval_df,
    metric='accuracy_minority',
    save_name='data_leakage'
)
# Out:
# [  2   4   8  16  32  64 128 256 512]
# [  2   4   8  16  32  64 128 256 512]
# (<Figure size 700x500 with 1 Axes>,
#  <Axes: xlabel='Number of context examples', ylabel='Minority-group accuracy'>)
